# %%
# 1A
def PatternCount(text, pattern):
    cnt = 0
    length = len(pattern)
    for i in range(len(text) - len(pattern) + 1):
        if text[i:i+length] == pattern:
            cnt += 1
    return cnt

text = '...'
pattern = 'AGGGGATAG'

print(PatternCount(text, pattern))
# Out:
# 29

# %%
# 1B
def FreqWords(text, k):
    Patterns = {}
    for i in range(len(text) - k + 1):
        pattern = text[i:i+k]
        count = PatternCount(text, pattern)
        Patterns.update({pattern : count})
    FreqPatterns = [k for k, v in Patterns.items() if v == max(Patterns.values())]
    return FreqPatterns

full_text = '''...
13
'''
text, k, _ = full_text.split('\n')
k = int(k)

# print(text, k)

for i in FreqWords(text, k):
    print(i, end = '\t')
# Out:
# CTTTCACTTGGTA	TTTCACTTGGTAG	TTCACTTGGTAGA	TCACTTGGTAGAC	CACTTGGTAGACC

# %%
with open('rosalind_ba1f.txt', "r") as f:
    content = f.read()
    
content
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open('Bioinfo algorithm/rosalind_ba1f.txt', "r") as f:
#       2     content = f.read()
#       4 content
#
# File /opt/homebrew/lib/python3.13/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Bioinfo algorithm/rosalind_ba1f.txt'
